# %%
import pandas as pd

# 數據下載的URL
url = "https://covid-19.nchc.org.tw/2023_dt_csv.php?dt_name=28"

# 使用pandas的read_csv函數將數據讀取到DataFrame中
df = pd.read_csv(url)

# 刪除 '個案發病日' 和 '七天移動平均新增確診人數' 這兩列
df = df.drop(['個案發病日', '七天移動平均新增確診人數'], axis=1)

# 排除全球和高收入地區的數據
df_filtered = df[~df['iso_code'].isin(['OWID_WRL', 'OWID_HIC', 'OWID_UMC', 'OWID_LMC'])]

# 按照累計確診人數從高到低排序
df_sorted = df_filtered.sort_values(by='累計確診人數', ascending=False)

# 選取前100行
top_100_countries = df_sorted.head(100)

# 使用styler設定顯示風格
styled_df = top_100_countries.style\
    .background_gradient(cmap='viridis', subset=['新增確診人數', '累計確診人數', '每百萬人確診數', '總人口數'])\
    .format({'每百萬人確診數': "{:.2f}", '總人口數': "{:,}"})

# 顯示漂亮格式的數據
styled_df
# Out:
# <style type="text/css">
# #T_01680_row0_col3, #T_01680_row0_col4, #T_01680_row1_col6, #T_01680_row91_col5 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_01680_row0_col5 {
#   background-color: #24868e;
#   color: #f1f1f1;
# }
# #T_01680_row0_col6 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_01680_row1_col3 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_01680_row1_col4 {
#   background-color: #9bd93c;
#   color: #000000;
# }
# #T_01680_row1_col5, #T_01680_row25_col6 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_01680_row2_col3 {
#   background-color: #69cd5b;
#   color: #000000;
# }
# #T_01680_row2_col4 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_01680_row2_col5 {
#   background-color: #1f9f88;
#   color: #f1f1f1;
# }
# #T_01680_row2_col6, #T_01680_row10_col3, #T_01680_row14_col5 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_01680_row3_col3, #T_01680_row46_col5 {
#   background-color: #1f978b;
#   color: #f1f1f1;
# }
# #T_01680_row3_col4 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_01680_row3_col5, #T_01680_row3_col6 {
#   background-color: #375a8c;
#   color: #f1f1f1;
# }
# #T_01680_row4_col3 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_01680_row4_col4, #T_01680_row77_col5 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_01680_row4_col5 {
#   background-color: #287d8e;
#   color: #f1f1f1;
# }
# #T_01680_row4_col6, #T_01680_row7_col4, #T_01680_row19_col5 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_01680_row5_col3, #T_01680_row6_col5, #T_01680_row15_col6, #T_01680_row24_col6, #T_01680_row88_col5 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_01680_row5_col4 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_01680_row5_col5, #T_01680_row58_col5, #T_01680_row89_col5 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_01680_row5_col6, #T_01680_row34_col5 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_01680_row6_col3, #T_01680_row23_col6, #T_01680_row26_col3, #T_01680_row31_col6, #T_01680_row32_col6, #T_01680_row35_col6, #T_01680_row37_col6, #T_01680_row38_col6, #T_01680_row47_col6, #T_01680_row51_col4, #T_01680_row52_col4, #T_01680_row53_col4, #T_01680_row54_col4, #T_01680_row54_col6, #T_01680_row55_col4, #T_01680_row56_col4, #T_01680_row57_col4, #T_01680_row58_col4, #T_01680_row58_col6, #T_01680_row59_col4, #T_01680_row60_col4, #T_01680_row60_col5, #T_01680_row61_col4, #T_01680_row62_col4, #T_01680_row63_col4, #T_01680_row72_col6, #T_01680_row73_col6, #T_01680_row74_col6, #T_01680_row76_col3, #T_01680_row76_col6, #T_01680_row81_col6, #T_01680_row84_col6, #T_01680_row90_col6, #T_01680_row93_col3, #T_01680_row96_col5 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_01680_row6_col4, #T_01680_row14_col3 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_01680_row6_col6 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_01680_row7_col3, #T_01680_row11_col4 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_01680_row7_col5 {
#   background-color: #7fd34e;
#   color: #000000;
# }
# #T_01680_row7_col6, #T_01680_row13_col6, #T_01680_row24_col4, #T_01680_row25_col4, #T_01680_row38_col3, #T_01680_row43_col6, #T_01680_row83_col5 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_01680_row8_col3 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_01680_row8_col4, #T_01680_row76_col5 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_01680_row8_col5 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_01680_row8_col6, #T_01680_row21_col4, #T_01680_row22_col4, #T_01680_row33_col3 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_01680_row9_col3, #T_01680_row12_col3, #T_01680_row13_col3, #T_01680_row15_col3, #T_01680_row16_col3, #T_01680_row17_col3, #T_01680_row19_col3, #T_01680_row20_col3, #T_01680_row21_col3, #T_01680_row22_col3, #T_01680_row28_col3, #T_01680_row29_col6, #T_01680_row30_col3, #T_01680_row31_col3, #T_01680_row32_col3, #T_01680_row34_col3, #T_01680_row35_col3, #T_01680_row36_col3, #T_01680_row37_col3, #T_01680_row40_col3, #T_01680_row41_col6, #T_01680_row42_col3, #T_01680_row43_col3, #T_01680_row44_col3, #T_01680_row44_col6, #T_01680_row45_col3, #T_01680_row46_col3, #T_01680_row46_col6, #T_01680_row47_col3, #T_01680_row48_col6, #T_01680_row49_col6, #T_01680_row50_col3, #T_01680_row51_col3, #T_01680_row51_col5, #T_01680_row52_col3, #T_01680_row52_col6, #T_01680_row53_col3, #T_01680_row53_col6, #T_01680_row54_col3, #T_01680_row55_col3, #T_01680_row56_col3, #T_01680_row56_col5, #T_01680_row57_col3, #T_01680_row57_col6, #T_01680_row58_col3, #T_01680_row59_col3, #T_01680_row59_col6, #T_01680_row60_col3, #T_01680_row61_col3, #T_01680_row62_col3, #T_01680_row62_col6, #T_01680_row63_col3, #T_01680_row63_col6, #T_01680_row64_col4, #T_01680_row64_col6, #T_01680_row65_col4, #T_01680_row65_col6, #T_01680_row66_col3, #T_01680_row66_col4, #T_01680_row66_col6, #T_01680_row67_col3, #T_01680_row67_col4, #T_01680_row68_col3, #T_01680_row68_col4, #T_01680_row68_col6, #T_01680_row69_col3, #T_01680_row69_col4, #T_01680_row70_col3, #T_01680_row70_col4, #T_01680_row70_col6, #T_01680_row71_col3, #T_01680_row71_col4, #T_01680_row71_col6, #T_01680_row72_col3, #T_01680_row72_col4, #T_01680_row73_col3, #T_01680_row73_col4, #T_01680_row74_col3, #T_01680_row74_col4, #T_01680_row75_col3, #T_01680_row75_col4, #T_01680_row76_col4, #T_01680_row77_col3, #T_01680_row77_col4, #T_01680_row77_col6, #T_01680_row78_col3, #T_01680_row78_col4, #T_01680_row78_col6, #T_01680_row79_col3, #T_01680_row79_col4, #T_01680_row79_col6, #T_01680_row80_col3, #T_01680_row80_col4, #T_01680_row81_col3, #T_01680_row81_col4, #T_01680_row82_col3, #T_01680_row82_col4, #T_01680_row82_col6, #T_01680_row83_col3, #T_01680_row83_col4, #T_01680_row84_col3, #T_01680_row84_col4, #T_01680_row85_col3, #T_01680_row85_col4, #T_01680_row85_col6, #T_01680_row86_col4, #T_01680_row86_col6, #T_01680_row87_col3, #T_01680_row87_col4, #T_01680_row87_col6, #T_01680_row88_col3, #T_01680_row88_col4, #T_01680_row89_col3, #T_01680_row89_col4, #T_01680_row89_col6, #T_01680_row90_col3, #T_01680_row90_col4, #T_01680_row91_col3, #T_01680_row91_col4, #T_01680_row91_col6, #T_01680_row92_col3, #T_01680_row92_col4, #T_01680_row93_col4, #T_01680_row93_col6, #T_01680_row94_col3, #T_01680_row94_col4, #T_01680_row94_col6, #T_01680_row95_col3, #T_01680_row95_col4, #T_01680_row96_col3, #T_01680_row96_col4, #T_01680_row97_col3, #T_01680_row97_col4, #T_01680_row97_col6, #T_01680_row98_col3, #T_01680_row98_col4, #T_01680_row98_col5, #T_01680_row99_col3, #T_01680_row99_col4, #T_01680_row99_col6 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_01680_row9_col4 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_01680_row9_col5 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_01680_row9_col6, #T_01680_row12_col4, #T_01680_row97_col5 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_01680_row10_col4 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_01680_row10_col5 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_01680_row10_col6, #T_01680_row98_col6 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_01680_row11_col3, #T_01680_row27_col5 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_01680_row11_col5 {
#   background-color: #84d44b;
#   color: #000000;
# }
# #T_01680_row11_col6, #T_01680_row12_col6, #T_01680_row26_col4, #T_01680_row27_col4, #T_01680_row28_col4, #T_01680_row28_col6, #T_01680_row41_col3, #T_01680_row92_col6, #T_01680_row95_col5 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_01680_row12_col5 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_01680_row13_col4 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_01680_row13_col5, #T_01680_row49_col5 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_01680_row14_col4, #T_01680_row36_col5 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_01680_row14_col6, #T_01680_row15_col4 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_01680_row15_col5 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_01680_row16_col4, #T_01680_row17_col4, #T_01680_row42_col6, #T_01680_row96_col6 {
#   background-col

# %%
import plotly.express as px

# 使用 Plotly Express 創建地圖
fig = px.scatter_geo(df, 
                     locations="iso_code",  # 使用 iso_code 作為位置信息
                     color="累計確診人數",      # 用顏色表示累計確診人數
                     hover_name="國家",       # 滑鼠懸停時顯示國家名稱
                     size="累計確診人數",       # 用點的大小表示確診人數
                     projection="natural earth",  # 地圖投影方式
                     title="全球確診病例數地圖",
                     size_max=70,  # 點的最大大小
                     range_color=[0, 115000000],  # 顏色範圍
                     template="none")  # 無背景樣式

# 顯示地圖
fig.show()
# Out:
# <div>                            <div id="edce49d6-122f-4cb9-ba00-f3239cb00eaa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edce49d6-122f-4cb9-ba00-f3239cb00eaa")) {                    Plotly.newPlot(                        "edce49d6-122f-4cb9-ba00-f3239cb00eaa",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>\u7d2f\u8a08\u78ba\u8a3a\u4eba\u6578=%{marker.color}<br>iso_code=%{location}<extra></extra>","hovertext":["North Korea","Vatican","International","Saint Kitts and","Turks and Caicos","Sao Tome and Pri","Palau","Eritrea","Saint Vincent an","Niger","Djibouti","Nicaragua","Marshall Islands","Central African","Vanuatu","Greenland","Yemen","Bonaire Sint Eus","Sierra Leone","Chad","British Virgin I","Cook Islands","Gambia","Antigua and Barb","Comoros","Guinea-Bissau","Liberia","Peru","Switzerland","Philippines","South Africa","Turkey","Oceania","Spain","Africa","Vietnam","Australia","Argentina","Taiwan","World","High income","